# %% [markdown]
# # Exercise 1: Load the Tips Dataset
# - Import the necessary libraries (seaborn, matplotlib.pyplot, and pandas).
# - Load the Tips dataset from Seaborn.

# %%
import pandas as pd

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %% [markdown]
# # Exercise 2: Scatter Plot

# %% [markdown]
# - Create a scatter plot using Seaborn to visualize the relationship between total_bill and tip.
#
# - Add different colors for different days of the week.

# %%
import seaborn as sns

# %%
sns.scatterplot(x=df['total_bill'],y=df['tip'],hue=df['day'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Exercise 3: Histogram
# - Create a histogram of the total_bill column using Matplotlib.

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['total_bill'],bins=20, edgecolor = 'Black')
plt.show()

# %% [markdown]
# # Exercise 4: Heatmap
# - Create a heatmap of the correlation matrix of the numerical columns in the Tips dataset using Seaborn.

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr,annot=True,cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# # Exercise 5: Bar Plot
# - Create a bar plot to show the average tip amount for each day using Seaborn.

# %%
sns.barplot(x=df['day'],y=df['tip'],estimator='mean',errorbar=('ci', False),hue=df['smoker'],palette='mako')
plt.show()

# %% [markdown]
# # Exercise 6: Line Plot
# - Create a line plot to show the trend of tip amount over total_bill using Matplotlib.

# %%
sns.lineplot(x=df['total_bill'],y=df['tip'] )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Exercise 7: Scatter Plots with Subplots
# - Create a figure with two subplots (1 row, 2 columns).
# - In the first subplot, create a scatter plot of total_bill vs tip.
# - In the second subplot, create a scatter plot of total_bill vs size.

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.scatterplot(x='total_bill', y='tip', data=df)
plt.subplot(1,2,2)
sns.scatterplot(x='total_bill', y='size', data=df)
plt.tight_layout() ## do space between graphes h_pad or v_pad
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad: 'float' = 1.08, h_pad: 'float | None' = None, w_pad: 'float | None' = None, rect: 'tuple[float, float, float, float] | None' = None) -> 'None'>

# %% [markdown]
# # Exercise 8: 2x2 Grid of Subplot
# - Plot the following in each subplot:
# - (1, 1): Scatter plot of total_bill vs tip
# - (1, 2): Histogram of total_bill
# - (2, 1): Box plot of total_bill by day
# - (2, 2): lineplot plot of total_bill vs tip

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.scatterplot(x='total_bill', y='tip', data=df)
plt.subplot(2,2,2)
sns.histplot(df['total_bill'])
plt.subplot(2,2,3)
sns.boxplot(x=df['total_bill'],y=df['day'])
plt.subplot(2,2,4)
sns.lineplot(x=df['total_bill'],y=df['tip'] )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Exercise 9: Customizing Subplot:
# - Plot the following in each subplot:
# - (1, 1): Line plot of total_bill vs tip
# - (2, 1): Bar plot of the average tip amount for each day
# - (3, 1): Heatmap of the correlation matrix

# %%
plt.figure(figsize=(10,15))
plt.subplot(3,1,1)
sns.lineplot(x=df['total_bill'],y=df['tip'] )
plt.subplot(3,1,2)
sns.barplot(x=df['day'],y=df['tip'],ci=False,estimator='mean')
plt.subplot(3,1,3)
corr = df.corr(numeric_only=True)
sns.heatmap(corr,annot=True)

plt.tight_layout(h_pad=5,w_pad=5)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3904\2042171904.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x=df['day'],y=df['tip'],ci=False,estimator='mean')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['sex'].value_counts().index
# Out:
# Index(['Male', 'Female'], dtype='object', name='sex')

# %%
plt.pie(df["sex"].value_counts(), autopct='%1.0f%%',colors=["teal","orange"],labels=df['sex'].value_counts().index)
plt.legend()
plt.show()

# %%
plt.pie(df["time"].value_counts(), autopct='%1.0f%%',colors=["teal","orange"],labels=df['time'].value_counts().index)
plt.legend()
plt.show()

# %%
dinner= df[df['time'] == 'Dinner']
lunch = df[df['time'] == 'Lunch'] 
dinner['time']
lunch['time']
# Out:
# 77     Lunch
# 78     Lunch
# 79     Lunch
# 80     Lunch
# 81     Lunch
#        ...
# 222    Lunch
# 223    Lunch
# 224    Lunch
# 225    Lunch
# 226    Lunch
# Name: time, Length: 68, dtype: object

# %%
# sns.barplot(x=dinner['time'],y=df['tip'])
# Out:
# <Axes: xlabel='time', ylabel='tip'>
